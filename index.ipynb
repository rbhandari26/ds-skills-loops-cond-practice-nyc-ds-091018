# %% [markdown]
# # Loops Review

# %%
for i in range(6):
    print(i, i**2)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25

# %% [markdown]
# ### Brief Notes
# Notice above that we used `for i in range(5)` which includes 5 elements but starts with 0 and ends with 4.
# If we wanted the numbers 1 through 5 we would instead use the loop `for i in range(1,6)`.

# %% [markdown]
# # Booleans and Conditionals Review

# %% [markdown]
# ## A simple example

# %%
print('This is the start of the program.')
print('This is the start of iteration.')
for i in range(12):
    #This is the start of the for loop.
    print('i is: {}'.format(i)) #This happens every iteration
    
    if i % 2 == 0:
        print('i is even')
    elif i in [3,5,7,11]:
        print('i is prime!')
    elif i == 4:
        print('i is 4') #This will never actually happen because the conditional terminates since 4 is also even
    else:
        print('i is odd, but not prime')
    
    print('\n') #This is outside both conditional blocks. This happens once per iteration
    #Iteration completes, program returns to start of iteration block.
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of iteration.
# i is: 0
# i is even
#
#
# i is: 1
# i is odd, but not prime
#
#
# i is: 2
# i is even
#
#
# i is: 3
# i is prime!
#
#
# i is: 4
# i is even
#
#
# i is: 5
# i is prime!
#
#
# i is: 6
# i is even
#
#
# i is: 7
# i is prime!
#
#
# i is: 8
# i is even
#
#
# i is: 9
# i is odd, but not prime
#
#
# i is: 10
# i is even
#
#
# i is: 11
# i is prime!
#
#
# For loop complete.
# Script complete.

# %% [markdown]
# ### Brief notes
# Notice the common conditional `i % 2 == 0` which is used to determine if a number is even (or odd). Recall that the `%` operator returns the remainder when dividing i by 2. Equivalently, this is i mod 2.
#
# Also note that the second elif clause `elif i == 4` is never executed because the conditional block completes as soon as a clause is true. In the below example, we examine how multiple conditional blocks can be chained.
#
# Another style that can be explored is combining multiple conditions such as `if i > 5 and i < 10:` or `if i == 7 or i > 8:`. In general, combining statements such as this should be used as opposed to nesting conditional blocks within each other which can become difficult to read. For example:

# %%
for i in range(50):
    if i >5:
        #Works but cautionary style. Often can become difficult to read. Do not overnest conditionals.
        if i < 10:
            print(i)#to be executed
# Out:
# 6
# 7
# 8
# 9

# %% [markdown]
# ## A complex example

# %%
print('This is the start of the program.')
print('This is the start of iteration.')
for i in range(12):
    #This is the start of the for loop.
    print('i is: {}'.format(i)) #This happens every iteration
    print('This is the first condition block.')
    #This is the start of our conditional block
    if i < 6:
        print('i is less then 6') #This is inside the 'if i < 6 condition'
    elif i % 2 == 0:
        print('i is even') #This is inside the 'elif i % 2 == 0 condition'
        print('this statement only executes if the if condition above (i<6) is false.')
        #The elif condition is only reached if the preceeding if statement is false.
        #Once one of the branches is triggered, the program exits this entire conditional block
    elif i == 7:
        print('i is 7!')
    else:
        print('Bigger then 7, and odd')
    #End of first conditional block
    
    #Start of second conditional block
    print('This is the second condition block.')
    if i % 2 == 0:
        print('i is even')
    else:
        print('i is odd')
    #End of second contional block
    
    print('\n') #This is outside both conditional blocks. This happens once per iteration
    #Iteration completes, program returns to start of iteration block.
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of iteration.
# i is: 0
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is even
#
#
# i is: 1
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is odd
#
#
# i is: 2
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is even
#
#
# i is: 3
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is odd
#
#
# i is: 4
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is even
#
#
# i is: 5
# This is the first condition block.
# i is less then 6
# This is the second condition block.
# i is odd
#
#
# i is: 6
# This is the first condition block.
# i is even
# this statement only executes if the if condition above (i<6) is false.
# This is the second condition block.
# i is even
#
#
# i is: 7
# This is the first condition block.
# i is 7!
# This is the second condition block.
# i is odd
#
#
# i is: 8
# This is the first condition block.
# i is even
# this statement only executes if the if condition above (i<6) is false.
# This is the second condition block.
# i is even
#
#
# i is: 9
# This is the first condition block.
# Bigger then 7, and odd
# This is the second condition block.
# i is odd
#
#
# i is: 10
# This is the first condition block.
# i is even
# this statement only executes if the if condition above (i<6) is false.
# This is the second condition block.
# i is even
#
#
# i is: 11
# This is the first condition block.
# Bigger then 7, and odd
# This is the second condition block.
# i is odd
#
#
# For loop complete.
# Script complete.

# %% [markdown]
# # Biz Buzz Bop
# You can quickly generate a list of numbers by using the range function. Use a for loop to iterate through the numbers 1 to 100, inclusive, print the number n, along with the following conditional actions:
#
# * If  n is odd, print ‘is odd’
# * If  n is even and divisible by 7, print ‘is divisible by 14’
# * If  n is divisible by 5, but not even, print ‘high five!’
# * If  n is greater than 30, less then 45 and divisible by 8, print ‘this happens twice!’

# %%
# Yprint("This is the start of the program.")
print("This is the start of the interation.")
for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if i % 2 ==0:
        print ("i is even")
    else:
        print("i is odd")
    print("\n") #This happens once per iteration
    #Iteration completes, program returns to start of iteration block.
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the interation.
# i is: 1
# i is odd
#
#
# i is: 2
# i is even
#
#
# i is: 3
# i is odd
#
#
# i is: 4
# i is even
#
#
# i is: 5
# i is odd
#
#
# i is: 6
# i is even
#
#
# i is: 7
# i is odd
#
#
# i is: 8
# i is even
#
#
# i is: 9
# i is odd
#
#
# i is: 10
# i is even
#
#
# i is: 11
# i is odd
#
#
# i is: 12
# i is even
#
#
# i is: 13
# i is odd
#
#
# i is: 14
# i is even
#
#
# i is: 15
# i is odd
#
#
# i is: 16
# i is even
#
#
# i is: 17
# i is odd
#
#
# i is: 18
# i is even
#
#
# i is: 19
# i is odd
#
#
# i is: 20
# i is even
#
#
# i is: 21
# i is odd
#
#
# i is: 22
# i is even
#
#
# i is: 23
# i is odd
#
#
# i is: 24
# i is even
#
#
# i is: 25
# i is odd
#
#
# i is: 26
# i is even
#
#
# i is: 27
# i is odd
#
#
# i is: 28
# i is even
#
#
# i is: 29
# i is odd
#
#
# i is: 30
# i is even
#
#
# i is: 31
# i is odd
#
#
# i is: 32
# i is even
#
#
# i is: 33
# i is odd
#
#
# i is: 34
# i is even
#
#
# i is: 35
# i is odd
#
#
# i is: 36
# i is even
#
#
# i is: 37
# i is odd
#
#
# i is: 38
# i is even
#
#
# i is: 39
# i is odd
#
#
# i is: 40
# i is even
#
#
# i is: 41
# i is odd
#
#
# i is: 42
# i is even
#
#
# i is: 43
# i is odd
#
#
# i is: 44
# i is even
#
#
# i is: 45
# i is odd
#
#
# i is: 46
# i is even
#
#
# i is: 47
# i is odd
#
#
# i is: 48
# i is even
#
#
# i is: 49
# i is odd
#
#
# i is: 50
# i is even
#
#
# i is: 51
# i is odd
#
#
# i is: 52
# i is even
#
#
# i is: 53
# i is odd
#
#
# i is: 54
# i is even
#
#
# i is: 55
# i is odd
#
#
# i is: 56
# i is even
#
#
# i is: 57
# i is odd
#
#
# i is: 58
# i is even
#
#
# i is: 59
# i is odd
#
#
# i is: 60
# i is even
#
#
# i is: 61
# i is odd
#
#
# i is: 62
# i is even
#
#
# i is: 63
# i is odd
#
#
# i is: 64
# i is even
#
#
# i is: 65
# i is odd
#
#
# i is: 66
# i is even
#
#
# i is: 67
# i is odd
#
#
# i is: 68
# i is even
#
#
# i is: 69
# i is odd
#
#
# i is: 70
# i is even
#
#
# i is: 71
# i is odd
#
#
# i is: 72
# i is even
#
#
# i is: 73
# i is odd
#
#
# i is: 74
# i is even
#
#
# i is: 75
# i is odd
#
#
# i is: 76
# i is even
#
#
# i is: 77
# i is odd
#
#
# i is: 78
# i is even
#
#
# i is: 79
# i is odd
#
#
# i is: 80
# i is even
#
#
# i is: 81
# i is odd
#
#
# i is: 82
# i is even
#
#
# i is: 83
# i is odd
#
#
# i is: 84
# i is even
#
#
# i is: 85
# i is odd
#
#
# i is: 86
# i is even
#
#
# i is: 87
# i is odd
#
#
# i is: 88
# i is even
#
#
# i is: 89
# i is odd
#
#
# i is: 90
# i is even
#
#
# i is: 91
# i is odd
#
#
# i is: 92
# i is even
#
#
# i is: 93
# i is odd
#
#
# i is: 94
# i is even
#
#
# i is: 95
# i is odd
#
#
# i is: 96
# i is even
#
#
# i is: 97
# i is odd
#
#
# i is: 98
# i is even
#
#
# i is: 99
# i is odd
#
#
# i is: 100
# i is even
#
#
# For loop complete.
# Script complete.

# %%
print("This is the start of the program.")
print("This is the start of the interation.")
for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if i % 2 ==0:
        print ("i is even")
    else:
        print("i is odd")
    print("\n") #This happens once per iteration
    #Iteration completes, program returns to start of iteration block.
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of the interation.
# i is: 1
# i is odd
#
#
# i is: 2
# i is even
#
#
# i is: 3
# i is odd
#
#
# i is: 4
# i is even
#
#
# i is: 5
# i is odd
#
#
# i is: 6
# i is even
#
#
# i is: 7
# i is odd
#
#
# i is: 8
# i is even
#
#
# i is: 9
# i is odd
#
#
# i is: 10
# i is even
#
#
# i is: 11
# i is odd
#
#
# i is: 12
# i is even
#
#
# i is: 13
# i is odd
#
#
# i is: 14
# i is even
#
#
# i is: 15
# i is odd
#
#
# i is: 16
# i is even
#
#
# i is: 17
# i is odd
#
#
# i is: 18
# i is even
#
#
# i is: 19
# i is odd
#
#
# i is: 20
# i is even
#
#
# i is: 21
# i is odd
#
#
# i is: 22
# i is even
#
#
# i is: 23
# i is odd
#
#
# i is: 24
# i is even
#
#
# i is: 25
# i is odd
#
#
# i is: 26
# i is even
#
#
# i is: 27
# i is odd
#
#
# i is: 28
# i is even
#
#
# i is: 29
# i is odd
#
#
# i is: 30
# i is even
#
#
# i is: 31
# i is odd
#
#
# i is: 32
# i is even
#
#
# i is: 33
# i is odd
#
#
# i is: 34
# i is even
#
#
# i is: 35
# i is odd
#
#
# i is: 36
# i is even
#
#
# i is: 37
# i is odd
#
#
# i is: 38
# i is even
#
#
# i is: 39
# i is odd
#
#
# i is: 40
# i is even
#
#
# i is: 41
# i is odd
#
#
# i is: 42
# i is even
#
#
# i is: 43
# i is odd
#
#
# i is: 44
# i is even
#
#
# i is: 45
# i is odd
#
#
# i is: 46
# i is even
#
#
# i is: 47
# i is odd
#
#
# i is: 48
# i is even
#
#
# i is: 49
# i is odd
#
#
# i is: 50
# i is even
#
#
# i is: 51
# i is odd
#
#
# i is: 52
# i is even
#
#
# i is: 53
# i is odd
#
#
# i is: 54
# i is even
#
#
# i is: 55
# i is odd
#
#
# i is: 56
# i is even
#
#
# i is: 57
# i is odd
#
#
# i is: 58
# i is even
#
#
# i is: 59
# i is odd
#
#
# i is: 60
# i is even
#
#
# i is: 61
# i is odd
#
#
# i is: 62
# i is even
#
#
# i is: 63
# i is odd
#
#
# i is: 64
# i is even
#
#
# i is: 65
# i is odd
#
#
# i is: 66
# i is even
#
#
# i is: 67
# i is odd
#
#
# i is: 68
# i is even
#
#
# i is: 69
# i is odd
#
#
# i is: 70
# i is even
#
#
# i is: 71
# i is odd
#
#
# i is: 72
# i is even
#
#
# i is: 73
# i is odd
#
#
# i is: 74
# i is even
#
#
# i is: 75
# i is odd
#
#
# i is: 76
# i is even
#
#
# i is: 77
# i is odd
#
#
# i is: 78
# i is even
#
#
# i is: 79
# i is odd
#
#
# i is: 80
# i is even
#
#
# i is: 81
# i is odd
#
#
# i is: 82
# i is even
#
#
# i is: 83
# i is odd
#
#
# i is: 84
# i is even
#
#
# i is: 85
# i is odd
#
#
# i is: 86
# i is even
#
#
# i is: 87
# i is odd
#
#
# i is: 88
# i is even
#
#
# i is: 89
# i is odd
#
#
# i is: 90
# i is even
#
#
# i is: 91
# i is odd
#
#
# i is: 92
# i is even
#
#
# i is: 93
# i is odd
#
#
# i is: 94
# i is even
#
#
# i is: 95
# i is odd
#
#
# i is: 96
# i is even
#
#
# i is: 97
# i is odd
#
#
# i is: 98
# i is even
#
#
# i is: 99
# i is odd
#
#
# i is: 100
# i is even
#
#
# For loop complete.
# Script complete.

# %% [markdown]
# # Extension
# Write a condition to determine if the number is prime.

# %%
print("This is the start of the program.")
print("This is the start of the interation.")

for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if i % 2 ==0:
        print("i is even")
    if i % 7 ==0:
        print("Is divisible by 14")
    print("\n")
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of the interation.
# i is: 1
#
#
# i is: 2
# i is even
#
#
# i is: 3
#
#
# i is: 4
# i is even
#
#
# i is: 5
#
#
# i is: 6
# i is even
#
#
# i is: 7
# Is divisible by 14
#
#
# i is: 8
# i is even
#
#
# i is: 9
#
#
# i is: 10
# i is even
#
#
# i is: 11
#
#
# i is: 12
# i is even
#
#
# i is: 13
#
#
# i is: 14
# i is even
# Is divisible by 14
#
#
# i is: 15
#
#
# i is: 16
# i is even
#
#
# i is: 17
#
#
# i is: 18
# i is even
#
#
# i is: 19
#
#
# i is: 20
# i is even
#
#
# i is: 21
# Is divisible by 14
#
#
# i is: 22
# i is even
#
#
# i is: 23
#
#
# i is: 24
# i is even
#
#
# i is: 25
#
#
# i is: 26
# i is even
#
#
# i is: 27
#
#
# i is: 28
# i is even
# Is divisible by 14
#
#
# i is: 29
#
#
# i is: 30
# i is even
#
#
# i is: 31
#
#
# i is: 32
# i is even
#
#
# i is: 33
#
#
# i is: 34
# i is even
#
#
# i is: 35
# Is divisible by 14
#
#
# i is: 36
# i is even
#
#
# i is: 37
#
#
# i is: 38
# i is even
#
#
# i is: 39
#
#
# i is: 40
# i is even
#
#
# i is: 41
#
#
# i is: 42
# i is even
# Is divisible by 14
#
#
# i is: 43
#
#
# i is: 44
# i is even
#
#
# i is: 45
#
#
# i is: 46
# i is even
#
#
# i is: 47
#
#
# i is: 48
# i is even
#
#
# i is: 49
# Is divisible by 14
#
#
# i is: 50
# i is even
#
#
# i is: 51
#
#
# i is: 52
# i is even
#
#
# i is: 53
#
#
# i is: 54
# i is even
#
#
# i is: 55
#
#
# i is: 56
# i is even
# Is divisible by 14
#
#
# i is: 57
#
#
# i is: 58
# i is even
#
#
# i is: 59
#
#
# i is: 60
# i is even
#
#
# i is: 61
#
#
# i is: 62
# i is even
#
#
# i is: 63
# Is divisible by 14
#
#
# i is: 64
# i is even
#
#
# i is: 65
#
#
# i is: 66
# i is even
#
#
# i is: 67
#
#
# i is: 68
# i is even
#
#
# i is: 69
#
#
# i is: 70
# i is even
# Is divisible by 14
#
#
# i is: 71
#
#
# i is: 72
# i is even
#
#
# i is: 73
#
#
# i is: 74
# i is even
#
#
# i is: 75
#
#
# i is: 76
# i is even
#
#
# i is: 77
# Is divisible by 14
#
#
# i is: 78
# i is even
#
#
# i is: 79
#
#
# i is: 80
# i is even
#
#
# i is: 81
#
#
# i is: 82
# i is even
#
#
# i is: 83
#
#
# i is: 84
# i is even
# Is divisible by 14
#
#
# i is: 85
#
#
# i is: 86
# i is even
#
#
# i is: 87
#
#
# i is: 88
# i is even
#
#
# i is: 89
#
#
# i is: 90
# i is even
#
#
# i is: 91
# Is divisible by 14
#
#
# i is: 92
# i is even
#
#
# i is: 93
#
#
# i is: 94
# i is even
#
#
# i is: 95
#
#
# i is: 96
# i is even
#
#
# i is: 97
#
#
# i is: 98
# i is even
# Is divisible by 14
#
#
# i is: 99
#
#
# i is: 100
# i is even
#
#
# For loop complete.
# Script complete.

# %%
print("This is the start of the program.")
print("This is the start of the interation.")
for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if (i % i) ==1:
        print("i is a prime")
    elif (i % 1) ==i:
        print("i is a prime")

    #print("\n") #This happens once per iteration
    #Iteration completes, program returns to start of iteration block.
print("For loop complete.")
print("Script complete.")# Your code here
# Out:
# This is the start of the program.
# This is the start of the interation.
# i is: 1
# i is: 2
# i is: 3
# i is: 4
# i is: 5
# i is: 6
# i is: 7
# i is: 8
# i is: 9
# i is: 10
# i is: 11
# i is: 12
# i is: 13
# i is: 14
# i is: 15
# i is: 16
# i is: 17
# i is: 18
# i is: 19
# i is: 20
# i is: 21
# i is: 22
# i is: 23
# i is: 24
# i is: 25
# i is: 26
# i is: 27
# i is: 28
# i is: 29
# i is: 30
# i is: 31
# i is: 32
# i is: 33
# i is: 34
# i is: 35
# i is: 36
# i is: 37
# i is: 38
# i is: 39
# i is: 40
# i is: 41
# i is: 42
# i is: 43
# i is: 44
# i is: 45
# i is: 46
# i is: 47
# i is: 48
# i is: 49
# i is: 50
# i is: 51
# i is: 52
# i is: 53
# i is: 54
# i is: 55
# i is: 56
# i is: 57
# i is: 58
# i is: 59
# i is: 60
# i is: 61
# i is: 62
# i is: 63
# i is: 64
# i is: 65
# i is: 66
# i is: 67
# i is: 68
# i is: 69
# i is: 70
# i is: 71
# i is: 72
# i is: 73
# i is: 74
# i is: 75
# i is: 76
# i is: 77
# i is: 78
# i is: 79
# i is: 80
# i is: 81
# i is: 82
# i is: 83
# i is: 84
# i is: 85
# i is: 86
# i is: 87
# i is: 88
# i is: 89
# i is: 90
# i is: 91
# i is: 92
# i is: 93
# i is: 94
# i is: 95
# i is: 96
# i is: 97
# i is: 98
# i is: 99
# i is: 100
# For loop complete.
# Script complete.

# %%
print("This is the start of the program.")
print("This is the start of the interation.")

for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if i % 5 ==0:
        print("i is divisible by five")
    elif i % 2 ==0:
        print("WTF!")
    else:
        print("High Five!")
        #print("Is divisible by 14")
    print("\n")
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of the interation.
# i is: 1
# High Five!
#
#
# i is: 2
# WTF!
#
#
# i is: 3
# High Five!
#
#
# i is: 4
# WTF!
#
#
# i is: 5
# i is divisible by five
#
#
# i is: 6
# WTF!
#
#
# i is: 7
# High Five!
#
#
# i is: 8
# WTF!
#
#
# i is: 9
# High Five!
#
#
# i is: 10
# i is divisible by five
#
#
# i is: 11
# High Five!
#
#
# i is: 12
# WTF!
#
#
# i is: 13
# High Five!
#
#
# i is: 14
# WTF!
#
#
# i is: 15
# i is divisible by five
#
#
# i is: 16
# WTF!
#
#
# i is: 17
# High Five!
#
#
# i is: 18
# WTF!
#
#
# i is: 19
# High Five!
#
#
# i is: 20
# i is divisible by five
#
#
# i is: 21
# High Five!
#
#
# i is: 22
# WTF!
#
#
# i is: 23
# High Five!
#
#
# i is: 24
# WTF!
#
#
# i is: 25
# i is divisible by five
#
#
# i is: 26
# WTF!
#
#
# i is: 27
# High Five!
#
#
# i is: 28
# WTF!
#
#
# i is: 29
# High Five!
#
#
# i is: 30
# i is divisible by five
#
#
# i is: 31
# High Five!
#
#
# i is: 32
# WTF!
#
#
# i is: 33
# High Five!
#
#
# i is: 34
# WTF!
#
#
# i is: 35
# i is divisible by five
#
#
# i is: 36
# WTF!
#
#
# i is: 37
# High Five!
#
#
# i is: 38
# WTF!
#
#
# i is: 39
# High Five!
#
#
# i is: 40
# i is divisible by five
#
#
# i is: 41
# High Five!
#
#
# i is: 42
# WTF!
#
#
# i is: 43
# High Five!
#
#
# i is: 44
# WTF!
#
#
# i is: 45
# i is divisible by five
#
#
# i is: 46
# WTF!
#
#
# i is: 47
# High Five!
#
#
# i is: 48
# WTF!
#
#
# i is: 49
# High Five!
#
#
# i is: 50
# i is divisible by five
#
#
# i is: 51
# High Five!
#
#
# i is: 52
# WTF!
#
#
# i is: 53
# High Five!
#
#
# i is: 54
# WTF!
#
#
# i is: 55
# i is divisible by five
#
#
# i is: 56
# WTF!
#
#
# i is: 57
# High Five!
#
#
# i is: 58
# WTF!
#
#
# i is: 59
# High Five!
#
#
# i is: 60
# i is divisible by five
#
#
# i is: 61
# High Five!
#
#
# i is: 62
# WTF!
#
#
# i is: 63
# High Five!
#
#
# i is: 64
# WTF!
#
#
# i is: 65
# i is divisible by five
#
#
# i is: 66
# WTF!
#
#
# i is: 67
# High Five!
#
#
# i is: 68
# WTF!
#
#
# i is: 69
# High Five!
#
#
# i is: 70
# i is divisible by five
#
#
# i is: 71
# High Five!
#
#
# i is: 72
# WTF!
#
#
# i is: 73
# High Five!
#
#
# i is: 74
# WTF!
#
#
# i is: 75
# i is divisible by five
#
#
# i is: 76
# WTF!
#
#
# i is: 77
# High Five!
#
#
# i is: 78
# WTF!
#
#
# i is: 79
# High Five!
#
#
# i is: 80
# i is divisible by five
#
#
# i is: 81
# High Five!
#
#
# i is: 82
# WTF!
#
#
# i is: 83
# High Five!
#
#
# i is: 84
# WTF!
#
#
# i is: 85
# i is divisible by five
#
#
# i is: 86
# WTF!
#
#
# i is: 87
# High Five!
#
#
# i is: 88
# WTF!
#
#
# i is: 89
# High Five!
#
#
# i is: 90
# i is divisible by five
#
#
# i is: 91
# High Five!
#
#
# i is: 92
# WTF!
#
#
# i is: 93
# High Five!
#
#
# i is: 94
# WTF!
#
#
# i is: 95
# i is divisible by five
#
#
# i is: 96
# WTF!
#
#
# i is: 97
# High Five!
#
#
# i is: 98
# WTF!
#
#
# i is: 99
# High Five!
#
#
# i is: 100
# i is divisible by five
#
#
# For loop complete.
# Script complete.

# %%
print("This is the start of the program.")
print("This is the start of the interation.")

for i in range (1,101):
    #This is the start of the for loop.
    print("i is: {}".format(i)) #This happens ever iteration
    
    if i > 30:
        print("i is greater than 30") #This is inside the 'if i > 30 condition'
    elif i < 45:
        print("i is less than 45")  #This is inside the 'elif i < 45 condition'
        print('this statement only executes if the if condition above (i>30) is false.')
        #The elif condition is only reached if the preceeding if statement is false.
        #Once one of the branches is triggered, the program exits this entire conditional block
      #End of first conditional block
    
    #Start of second conditional block
    print('This is the second condition block.')
    if i % 8 == 0:
        print("this happens twice!")
    print("\n")
print('For loop complete.')
print('Script complete.')
# Out:
# This is the start of the program.
# This is the start of the interation.
# i is: 1
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 2
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 3
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 4
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 5
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 6
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 7
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 8
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
# this happens twice!
#
#
# i is: 9
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 10
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 11
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 12
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 13
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 14
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 15
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 16
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
# this happens twice!
#
#
# i is: 17
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 18
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 19
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 20
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 21
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 22
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 23
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 24
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
# this happens twice!
#
#
# i is: 25
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 26
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 27
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 28
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 29
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 30
# i is less than 45
# this statement only executes if the if condition above (i>30) is false.
# This is the second condition block.
#
#
# i is: 31
# i is greater than 30
# This is the second condition block.
#
#
# i is: 32
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 33
# i is greater than 30
# This is the second condition block.
#
#
# i is: 34
# i is greater than 30
# This is the second condition block.
#
#
# i is: 35
# i is greater than 30
# This is the second condition block.
#
#
# i is: 36
# i is greater than 30
# This is the second condition block.
#
#
# i is: 37
# i is greater than 30
# This is the second condition block.
#
#
# i is: 38
# i is greater than 30
# This is the second condition block.
#
#
# i is: 39
# i is greater than 30
# This is the second condition block.
#
#
# i is: 40
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 41
# i is greater than 30
# This is the second condition block.
#
#
# i is: 42
# i is greater than 30
# This is the second condition block.
#
#
# i is: 43
# i is greater than 30
# This is the second condition block.
#
#
# i is: 44
# i is greater than 30
# This is the second condition block.
#
#
# i is: 45
# i is greater than 30
# This is the second condition block.
#
#
# i is: 46
# i is greater than 30
# This is the second condition block.
#
#
# i is: 47
# i is greater than 30
# This is the second condition block.
#
#
# i is: 48
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 49
# i is greater than 30
# This is the second condition block.
#
#
# i is: 50
# i is greater than 30
# This is the second condition block.
#
#
# i is: 51
# i is greater than 30
# This is the second condition block.
#
#
# i is: 52
# i is greater than 30
# This is the second condition block.
#
#
# i is: 53
# i is greater than 30
# This is the second condition block.
#
#
# i is: 54
# i is greater than 30
# This is the second condition block.
#
#
# i is: 55
# i is greater than 30
# This is the second condition block.
#
#
# i is: 56
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 57
# i is greater than 30
# This is the second condition block.
#
#
# i is: 58
# i is greater than 30
# This is the second condition block.
#
#
# i is: 59
# i is greater than 30
# This is the second condition block.
#
#
# i is: 60
# i is greater than 30
# This is the second condition block.
#
#
# i is: 61
# i is greater than 30
# This is the second condition block.
#
#
# i is: 62
# i is greater than 30
# This is the second condition block.
#
#
# i is: 63
# i is greater than 30
# This is the second condition block.
#
#
# i is: 64
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 65
# i is greater than 30
# This is the second condition block.
#
#
# i is: 66
# i is greater than 30
# This is the second condition block.
#
#
# i is: 67
# i is greater than 30
# This is the second condition block.
#
#
# i is: 68
# i is greater than 30
# This is the second condition block.
#
#
# i is: 69
# i is greater than 30
# This is the second condition block.
#
#
# i is: 70
# i is greater than 30
# This is the second condition block.
#
#
# i is: 71
# i is greater than 30
# This is the second condition block.
#
#
# i is: 72
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 73
# i is greater than 30
# This is the second condition block.
#
#
# i is: 74
# i is greater than 30
# This is the second condition block.
#
#
# i is: 75
# i is greater than 30
# This is the second condition block.
#
#
# i is: 76
# i is greater than 30
# This is the second condition block.
#
#
# i is: 77
# i is greater than 30
# This is the second condition block.
#
#
# i is: 78
# i is greater than 30
# This is the second condition block.
#
#
# i is: 79
# i is greater than 30
# This is the second condition block.
#
#
# i is: 80
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 81
# i is greater than 30
# This is the second condition block.
#
#
# i is: 82
# i is greater than 30
# This is the second condition block.
#
#
# i is: 83
# i is greater than 30
# This is the second condition block.
#
#
# i is: 84
# i is greater than 30
# This is the second condition block.
#
#
# i is: 85
# i is greater than 30
# This is the second condition block.
#
#
# i is: 86
# i is greater than 30
# This is the second condition block.
#
#
# i is: 87
# i is greater than 30
# This is the second condition block.
#
#
# i is: 88
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 89
# i is greater than 30
# This is the second condition block.
#
#
# i is: 90
# i is greater than 30
# This is the second condition block.
#
#
# i is: 91
# i is greater than 30
# This is the second condition block.
#
#
# i is: 92
# i is greater than 30
# This is the second condition block.
#
#
# i is: 93
# i is greater than 30
# This is the second condition block.
#
#
# i is: 94
# i is greater than 30
# This is the second condition block.
#
#
# i is: 95
# i is greater than 30
# This is the second condition block.
#
#
# i is: 96
# i is greater than 30
# This is the second condition block.
# this happens twice!
#
#
# i is: 97
# i is greater than 30
# This is the second condition block.
#
#
# i is: 98
# i is greater than 30
# This is the second condition block.
#
#
# i is: 99
# i is greater than 30
# This is the second condition block.
#
#
# i is: 100
# i is greater than 30
# This is the second condition block.
#
#
# For loop complete.
# Script complete.
